# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import pydot
import graphviz
from keras.utils import plot_model

# %% [markdown]
# ## Preprocessing the Data

# %% [markdown]
# ### Load Data

# %%
def unpickle(file):
    with open(file, 'rb') as fo:
        dict = pickle.load(fo, encoding='bytes')
    return dict
data = unpickle(f'./Data/data_batch_1')
labels = data[b'labels']
images = data[b'data']
for i in range(2,6):
    data = unpickle(f'./Data/data_batch_{i}')
    labels = np.concatenate((labels, data[b'labels']))
    images = np.concatenate((images,data[b'data']))
data_test = unpickle(f'./Data/test_batch')

labels_test = data_test[b'labels']
images_test = data_test[b'data']
label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
images.shape
# Out:
# (50000, 3072)

# %% [markdown]
# ### Reshape Data

# %%
images = images.reshape(len(images),3,32,32).transpose(0,2,3,1)
images_test = images_test.reshape(len(images_test),3,32,32).transpose(0,2,3,1)
images.shape
# Out:
# (50000, 32, 32, 3)

# %% [markdown]
# ### Visualize Some Data

# %%
rows, columns = 5, 5
# take random image idex id
imageId = np.random.randint(0, len(images), rows * columns)
# take images for above random image ids
images_to_show = images[imageId]
# take labels for these images only
labels_to_show = [labels[i] for i in imageId]

# define figure
fig=plt.figure(figsize=(10, 10))
# visualize these random images
for i in range(1, columns*rows +1):
    fig.add_subplot(rows, columns, i)
    plt.imshow(images_to_show[i-1])
    plt.xticks([])
    plt.yticks([])
    plt.title("{}"
          .format(label_names[labels_to_show[i-1]]))
plt.show()

# %% [markdown]
# ### Image Augmentation

# %%
## Nothing for now

# %% [markdown]
# ## Model Definition

# %% [markdown]
# ### Residual Block Definition

# %%
def residual_block(X, num_filters: int, stride: int = 1, kernel_size: int = 3,
                   activation: str = 'relu', bn: bool = True, conv_first: bool = True):
    """
    Parameters
    ----------
    X : Tensor layer
        Input tensor from previous layer
    num_filters : int
        Conv2d number of filters
    stride : int by default 1
        Stride square dimension
    kernel_size : int by default 3
        COnv2D square kernel dimensions
    activation: str by default 'relu'
        Activation function to used
    bn: bool by default True
        To use BatchNormalization
    conv_first : bool by default True
        conv-bn-activation (True) or bn-activation-conv (False)
    """
    conv_layer = tf.keras.layers.Conv2D(num_filters,
                        kernel_size=kernel_size,
                        strides=stride,
                        padding='same',
                        kernel_regularizer=tf.keras.regularizers.L2(l2=0.0001))
    # X = input
    if conv_first:
        X = conv_layer(X)
        if bn:
            X = tf.keras.layers.BatchNormalization()(X)
        if activation is not None:
            X = tf.keras.layers.Activation(activation)(X)
            X = tf.keras.layers.Dropout(0.2)(X)
    else:
        if bn:
            X = tf.keras.layers.BatchNormalization()(X)
        if activation is not None:
            X = tf.keras.layers.Activation(activation)(X)
        X = conv_layer(X)

    return X

# %% [markdown]
# ### Full Model Definition

# %%
depth = 20
input_shape = [32, 32, 3]
num_filters_in = 32
num_classes = 10
def create_resnet(depth = depth, input_shape = input_shape, num_filters_in = num_filters_in, num_classes = num_classes):
    inputs = tf.keras.layers.Input(shape=input_shape)
    num_res_block = int((depth - 2) / 9)
    # ResNet V2 performs Conv2D on X before spiting into two path
    X = residual_block(X=inputs, num_filters=num_filters_in, conv_first=True)

    # Building stack of residual units
    for stage in range(3):
        for unit_res_block in range(num_res_block):
            activation = 'relu'
            bn = True
            stride = 1
            # First layer and first stage
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if unit_res_block == 0:
                    activation = None
                    bn = False
                # First layer but not first stage
            else:
                num_filters_out = num_filters_in * 2
                if unit_res_block == 0:
                    stride = 2

            # bottleneck residual unit
            y = residual_block(X,
                               num_filters=num_filters_in,
                               kernel_size=1,
                               stride=stride,
                               activation=activation,
                               bn=bn,
                               conv_first=False)
            y = residual_block(y,
                               num_filters=num_filters_in,
                               conv_first=False)
            y = residual_block(y,
                               num_filters=num_filters_out,
                               kernel_size=1,
                               conv_first=False)
            if unit_res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                X = residual_block(X=X,
                                   num_filters=num_filters_out,
                                   kernel_size=1,
                                   stride=stride,
                                   activation=None,
                                   bn=False)
            X = tf.keras.layers.add([X, y])
        num_filters_in = num_filters_out

    X = tf.keras.layers.BatchNormalization()(X)
    X = tf.keras.layers.Activation('relu')(X)
    X = tf.keras.layers.AveragePooling2D(pool_size=8)(X)
    y = tf.keras.layers.Flatten()(X)
    y = tf.keras.layers.Dense(512, activation='relu')(y)
    y = tf.keras.layers.BatchNormalization()(y)
    y = tf.keras.layers.Dropout(0.5)(y)

    outputs = tf.keras.layers.Dense(num_classes,
                    activation='softmax')(y)

    # Instantiate model.
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    return model

# %%
model = create_resnet()
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_13 (InputLayer)          [(None, 32, 32, 3)]  0           []
#
#  conv2d_154 (Conv2D)            (None, 32, 32, 32)   896         ['input_13[0][0]']
#
#  batch_normalization_140 (Batch  (None, 32, 32, 32)  128         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_140[0][0]']
#
#  dropout_14 (Dropout)           (None, 32, 32, 32)   0           ['activation_133[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 32, 32, 32)   1056        ['dropout_14[0][0]']
#
#  batch_normalization_141 (Batch  (None, 32, 32, 32)  128         ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_141[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_134[0][0]']
#
#  batch_normalization_142 (Batch  (None, 32, 32, 32)  128         ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_142[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 32, 32, 128)  4224        ['dropout_14[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 32, 32, 128)  4224        ['activation_135[0][0]']
#
#  add_42 (Add)                   (None, 32, 32, 128)  0           ['conv2d_158[0][0]',
#                                                                   'conv2d_157[0][0]']
#
#  batch_normalization_143 (Batch  (None, 32, 32, 128)  512        ['add_42[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 32, 32, 32)   4128        ['activation_136[0][0]']
#
#  batch_normalization_144 (Batch  (None, 32, 32, 32)  128         ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_137 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_144[0][0]']
#
#  conv2d_160 (Conv2D)            (None, 32, 32, 32)   9248        ['activation_137[0][0]']
#
#  batch_normalization_145 (Batch  (None, 32, 32, 32)  128         ['conv2d_160[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 32, 32, 32)   0           ['batch_normalization_145[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 32, 32, 128)  4224        ['activation_138[0][0]']
#
#  add_43 (Add)                   (None, 32, 32, 128)  0           ['add_42[0][0]',
#                                                                   'conv2d_161[0][0]']
#
#  batch_normalization_146 (Batch  (None, 32, 32, 128)  512        ['add_43[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_146[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 16, 16, 128)  16512       ['activation_139[0][0]']
#
#  batch_normalization_147 (Batch  (None, 16, 16, 128)  512        ['conv2d_162[0][0]']
#  Normalization)
#
#  activation_140 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_147[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 16, 16, 128)  147584      ['activation_140[0][0]']
#
#  batch_normalization_148 (Batch  (None, 16, 16, 128)  512        ['conv2d_163[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 16, 16, 256)  33024       ['add_43[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 16, 16, 256)  33024       ['activation_141[0][0]']
#
#  add_44 (Add)                   (None, 16, 16, 256)  0           ['conv2d_165[0][0]',
#                                                                   'conv2d_164[0][0]']
#
#  batch_normalization_149 (Batch  (None, 16, 16, 256)  1024       ['add_44[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 16, 16, 128)  32896       ['activation_142[0][0]']
#
#  batch_normalization_150 (Batch  (None, 16, 16, 128)  512        ['conv2d_166[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 16, 16, 128)  147584      ['activation_143[0][0]']
#
#  batch_normalization_151 (Batch  (None, 16, 16, 128)  512        ['conv2d_167[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 16, 16, 128)  0           ['batch_normalization_151[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 16, 16, 256)  33024       ['activation_144[0][0]']
#
#  add_45 (Add)                   (None, 16, 16, 256)  0           ['add_44[0][0]',
#                                                                   'conv2d_168[0][0]']
#
#  batch_normalization_152 (Batch  (None, 16, 16, 256)  1024       ['add_45[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 16, 16, 256)  0           ['batch_normalization_152[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 8, 8, 256)    65792       ['activation_145[0][0]']
#
#  batch_normalization_153 (Batch  (None, 8, 8, 256)   1024        ['conv2d_169[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_153[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 8, 8, 256)    590080      ['activation_146[0][0]']
#
#  batch_normalization_154 (Batch  (None, 8, 8, 256)   1024        ['conv2d_170[0][0]']
#  Normalization)
#
#  activation_147 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_154[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 8, 8, 512)    131584      ['add_45[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 8, 8, 512)    131584      ['activation_147[0][0]']
#
#  add_46 (Add)                   (None, 8, 8, 512)    0           ['conv2d_172[0][0]',
#                                                                   'conv2d_171[0][0]']
#
#  batch_normalization_155 (Batch  (None, 8, 8, 512)   2048        ['add_46[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_155[0][0]']
#
#  conv2d_173 (Conv2D)            (None, 8, 8, 256)    131328      ['activation_148[0][0]']
#
#  batch_normalization_156 (Batch  (None, 8, 8, 256)   1024        ['conv2d_173[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_156[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 8, 8, 256)    590080      ['activation_149[0][0]']
#
#  batch_normalization_157 (Batch  (None, 8, 8, 256)   1024        ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_150 (Activation)    (None, 8, 8, 256)    0           ['batch_normalization_157[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 8, 8, 512)    131584      ['activation_150[0][0]']
#
#  add_47 (Add)                   (None, 8, 8, 512)    0           ['add_46[0][0]',
#                                                                   'conv2d_175[0][0]']
#
#  batch_normalization_158 (Batch  (None, 8, 8, 512)   2048        ['add_47[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 8, 8, 512)    0           ['batch_normalization_158[0][0]']
#
#  average_pooling2d_7 (AveragePo  (None, 1, 1, 512)   0           ['activation_151[0][0]']
#  oling2D)
#
#  flatten_7 (Flatten)            (None, 512)          0           ['average_pooling2d_7[0][0]']
#
#  dense_14 (Dense)               (None, 512)          262656      ['flatten_7[0][0]']
#
#  batch_normalization_159 (Batch  (None, 512)         2048        ['dense_14[0][0]']
#  Normalization)
#
#  dropout_15 (Dropout)           (None, 512)          0           ['batch_normalization_159[0][0]']
#
#  dense_15 (Dense)               (None, 10)           5130        ['dropout_15[0][0]']
#
# ==================================================================================================
# Total params: 2,536,714
# Trainable params: 2,528,714
# Non-trainable params: 8,000
# __________________________________________________________________________________________________

# %%
model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
model.fit(x = images, y = np.array(labels), epochs = 20, validation_data = (images_test, np.array(labels_test)))
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 474s 303ms/step - loss: 0.9435 - accuracy: 0.7568 - val_loss: 1.6549 - val_accuracy: 0.5851
# Epoch 2/20
# 1563/1563 [==============================] - 462s 295ms/step - loss: 0.9003 - accuracy: 0.7740 - val_loss: 1.0375 - val_accuracy: 0.7419
# Epoch 3/20
# 1563/1563 [==============================] - 482s 308ms/step - loss: 0.8692 - accuracy: 0.7850 - val_loss: 1.1503 - val_accuracy: 0.7079
# Epoch 4/20
# 1563/1563 [==============================] - 482s 308ms/step - loss: 0.8362 - accuracy: 0.7975 - val_loss: 0.9959 - val_accuracy: 0.7499
# Epoch 5/20
# 1563/1563 [==============================] - 477s 305ms/step - loss: 0.8116 - accuracy: 0.8087 - val_loss: 1.1478 - val_accuracy: 0.7221
# Epoch 6/20
# 1563/1563 [==============================] - 459s 294ms/step - loss: 0.7876 - accuracy: 0.8159 - val_loss: 0.9246 - val_accuracy: 0.7711
# Epoch 7/20
# 1563/1563 [==============================] - 517s 331ms/step - loss: 0.7650 - accuracy: 0.8239 - val_loss: 1.0552 - val_accuracy: 0.7264
# Epoch 8/20
# 1563/1563 [==============================] - 465s 297ms/step - loss: 0.7460 - accuracy: 0.8305 - val_loss: 1.0288 - val_accuracy: 0.7496
# Epoch 9/20
# 1563/1563 [==============================] - 1298s 831ms/step - loss: 0.7321 - accuracy: 0.8375 - val_loss: 0.9925 - val_accuracy: 0.7496
# Epoch 10/20
# 1563/1563 [==============================] - 2602s 2s/step - loss: 0.7143 - accuracy: 0.8423 - val_loss: 1.2938 - val_accuracy: 0.6980
# Epoch 11/20
# 1563/1563 [==============================] - 2178s 1s/step - loss: 0.6989 - accuracy: 0.8507 - val_loss: 1.0105 - val_accuracy: 0.7600
# Epoch 12/20
# 1563/1563 [==============================] - 2431s 2s/step - loss: 0.6847 - accuracy: 0.8567 - val_loss: 0.8876 - val_accuracy: 0.7924
# Epoch 13/20
# 1563/1563 [==============================] - 474s 303ms/step - loss: 0.6801 - accuracy: 0.8581 - val_loss: 0.9657 - val_accuracy: 0.7632
# Epoch 14/20
# 1563/1563 [==============================] - 472s 302ms/step - loss: 0.6638 - accuracy: 0.8625 - val_loss: 0.9134 - val_accuracy: 0.7909
# Epoch 15/20
# 1563/1563 [==============================] - 470s 301ms/step - loss: 0.6546 - accuracy: 0.8653 - val_loss: 0.8881 - val_accuracy: 0.7948
# Epoch 16/20
# 1563/1563 [==============================] - 470s 300ms/step - loss: 0.6459 - accuracy: 0.8703 - val_loss: 0.9692 - val_accuracy: 0.7841
# Epoch 17/20
# 1563/1563 [==============================] - 470s 301ms/step - loss: 0.6308 - accuracy: 0.8771 - val_loss: 0.8055 - val_accuracy: 0.8273
# Epoch 18/20
# 1150/1563 [=====================>........] - ETA: 1:58 - loss: 0.6169 - accuracy: 0.8803

# %%
print(len(images))
# Out:
# 50000
